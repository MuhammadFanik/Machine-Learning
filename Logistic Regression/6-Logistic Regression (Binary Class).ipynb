# %% [markdown]
# # Predict if a person would buy life insurance based on his age using Logistic Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.sample(5)
# Out:
#     age  bought_insurance
# 14   49                 1
# 10   18                 0
# 21   26                 0
# 26   23                 0
# 2    47                 1

# %%
df.shape
# Out:
# (27, 2)

# %%
plt.scatter(df["age"], df["bought_insurance"], marker="+")
plt.grid()
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 0, 1, 0, 0, 0])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.29283564, 0.70716436],
#        [0.81249348, 0.18750652],
#        [0.27022949, 0.72977051],
#        [0.85835758, 0.14164242],
#        [0.73479072, 0.26520928],
#        [0.77603022, 0.22396978]])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
print(model.coef_[0][0])
# Out:
# 0.11180694473854132

# %%
print(model.intercept_[0])
# Out:
# -4.261467861358489
