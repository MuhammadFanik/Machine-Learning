# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Import the dataset
df = pd.read_csv("multiple_regression_data.csv")
df.head()
# Out:
#    study_hours  experience_years  projects_completed  performance_score
# 0         4.37              0.78                   5              18.98
# 1         9.56              7.97                  18              71.05
# 2         7.59              8.11                  10              48.12
# 3         6.39              9.56                   6              35.95
# 4         2.40             10.89                   1              22.70

# %%
df.shape
# Out:
# (300, 4)

# %%
# Separate the input and output cols
X = df[["study_hours", "experience_years", "projects_completed"]]
y = df["performance_score"]

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
# Create and train MLR
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Step 5: Display model coefficients
print("Intercept (β₀):", model.intercept_)
print("Coefficients (β):", model.coef_)
print("Feature names:", X.columns.tolist())
# Out:
# Intercept (β₀): 0.3127545493903412
# Coefficients (β): [3.20554719 1.45978092 1.95667091]
# Feature names: ['study_hours', 'experience_years', 'projects_completed']

# %% [markdown]
# ## Make Predictions

# %%
# Make predictions on my custom Values set
prediction = model.predict([[5, 3, 7]])
print(prediction[0])
# Out:
# 34.416529633612875
# D:\Complete DataScience\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Prediction on the test set
prediction1 = model.predict(X_test)
print(prediction1)
# Out:
# [49.23177445 40.02727807 18.92639065 33.77768969 41.61887632 48.50541608
#  66.57367161 40.99343465 39.16061504 32.24381965 31.16268936 57.21161549
#  73.2401719  55.6784478  67.53755298 53.67071878 25.85678419 58.07840894
#  17.13935966 61.26470722 43.45076748 66.77013848 76.34790179 31.22597662
#  46.49792524 45.48419908 69.94202113 62.22682136 45.52191441 55.49070086
#  53.75064944 35.00611729 39.30370626 66.91517167 40.31214876 57.06951222
#  59.0669604  50.19601721 40.13429789 67.44649439 48.45278824 46.2168944
#  55.79044202 52.58370553 17.91696714 41.40248344 41.6447061  62.18254834
#  58.31828695 55.55745613 56.48972717 64.73930837 36.8838186  41.30779865
#  46.76670355 46.29056863 29.15939156 62.97194119 72.73266991 71.69135882
#  53.71884188 33.33514799 34.09392881 79.4722374  66.75163623 56.24126774
#  59.66412745 51.08526239 32.10337371 41.76842098 31.90222476 56.34158785
#  63.79940267 41.5598702  46.26975507 29.05417406 44.44660465 65.77196474
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, prediction1)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 32.02
