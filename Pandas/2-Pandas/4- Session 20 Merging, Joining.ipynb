# %%
import numpy as np
import pandas as pd

# %%
course = pd.read_csv("D:/Complete DataScience/Pandas/2-Pandas/courses.csv")
deliver = pd.read_csv("D:/Complete DataScience/Pandas/2-Pandas/deliveries.csv")
match = pd.read_csv("D:/Complete DataScience/Pandas/2-Pandas/matches.csv")
reg1 = pd.read_csv("D:/Complete DataScience/Pandas/2-Pandas/reg-month1.csv")
reg2 = pd.read_csv("D:/Complete DataScience/Pandas/2-Pandas/reg-month2.csv")
student = pd.read_csv("D:/Complete DataScience/Pandas/2-Pandas/students.csv")

# %%
course.head()
# Out:
#    course_id       course_name  price
# 0          1            python   2499
# 1          2               sql   3499
# 2          3     data analysis   4999
# 3          4  machine learning   9999
# 4          5           tableau   2499

# %% [markdown]
# ## pd.concat

# %%
# Stack reg1 and reg2 vertically
nov_dec_regs = pd.concat([reg1, reg2], ignore_index=True)
nov_dec_regs.head()
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5
# 2          18          6
# 3          23          4
# 4          16          9

# %% [markdown]
# # Merge

# %%
student.head()
# Out:
#    student_id            name  partner
# 0           1   Kailash Harjo       23
# 1           2     Esha Butala        1
# 2           3  Parveen Bhalla        3
# 3           4     Marlo Dugal       14
# 4           5     Kusum Bahri        6

# %%
nov_dec_regs.head()
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5
# 2          18          6
# 3          23          4
# 4          16          9

# %%
print(student.shape)
print(nov_dec_regs.shape)
# Out:
# (25, 3)
# (53, 2)

# %%
# INNER JOIN
student.merge(right=nov_dec_regs, how="inner", on="student_id").head()
# Out:
#    student_id           name  partner  course_id
# 0           1  Kailash Harjo       23          1
# 1           1  Kailash Harjo       23          6
# 2           1  Kailash Harjo       23         10
# 3           1  Kailash Harjo       23          9
# 4           2    Esha Butala        1          5

# %%
# LEFT JOIN
# OUTER JOIN
# RIGHT JOIN already done before

# %% [markdown]
# ## Q1. Find the total revenue generated

# %%
course.head()
# Out:
#    course_id       course_name  price
# 0          1            python   2499
# 1          2               sql   3499
# 2          3     data analysis   4999
# 3          4  machine learning   9999
# 4          5           tableau   2499

# %%
total_revenue = nov_dec_regs.merge(course, how="inner", on="course_id")["price"].sum()
print(total_revenue)
# Out:
# 154247

# %% [markdown]
# ## Q2. Print the registration table
