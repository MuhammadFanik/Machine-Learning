# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 0-Tensor

# %%
a = np.array(3)
print(a)
print(a.ndim)
# Out:
# 3
# 0

# %% [markdown]
# # 1-Tensor

# %%
b = np.array([1, 2, 3])
print(b)
print(b.ndim)
# Out:
# [1 2 3]
# 1

# %% [markdown]
# # 2-Tensor

# %%
c = np.array([[4, 6, 7], [-7, -10, 20]])
print(c)
print(c.ndim)
# Out:
# [[  4   6   7]
#  [ -7 -10  20]]
# 2
