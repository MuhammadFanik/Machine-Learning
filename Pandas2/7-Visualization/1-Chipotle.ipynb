# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5. Create a histogram of the top 5 items bought
chipo.groupby("item_name")["quantity"].sum().sort_values(ascending=False).head(5).plot.barh()
plt.show()

# %%
# Step 6. Create a scatterplot with the number of items ordered per order price
dollarizer = lambda x: float(x[1:])
chipo["item_price"] = chipo["item_price"].apply(dollarizer)

# %%
chipo.groupby("item_price").sum()
# Out:
#             order_id  quantity  \
# item_price
# 1.09           84666       106
# 1.25          265250       264
# 1.50          130856       117
# 1.69           82040        99
# 1.99            1793         1
# ...              ...       ...
# 32.94            178         3
# 33.75           1443         3
# 35.00           1954         8
# 35.25           1398         3
# 44.25           1443        15
#
#                                                     item_name  \
# item_price
# 1.09        Canned SodaBottled WaterCanned SodaBottled Wat...
# 1.25        Canned Soft DrinkCanned Soft DrinkCanned Soft ...
# 1.50        Bottled WaterBottled WaterBottled WaterBottled...
# 1.69        Side of ChipsSide of ChipsSide of ChipsSide of...
# 1.99                                                    Chips
# ...                                                       ...
# 32.94                                            Chicken Bowl
# ...
